# %% [markdown]
# **Assignment 2:** Implement POS tagging on a text corpus using an NLP library (like NLTK or SpaCy).
# Analyze the grammatical structure of sentences using syntactic/dependency parsing.

# %% [markdown]
# # **Using NLTK;**

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# Download required resources (run once)
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
# Sample text
text = "The students are studying natural language processing to improve their understanding of grammar."

# %%
nltk.download('punkt_tab')
tokens = word_tokenize(text)
tokens
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# ['The',
#  'students',
#  'are',
#  'studying',
#  'natural',
#  'language',
#  'processing',
#  'to',
#  'improve',
#  'their',
#  'understanding',
#  'of',
#  'grammar',
#  '.']

# %%
nltk.download('averaged_perceptron_tagger_eng')
# POS Tagging
pos_tags = pos_tag(tokens)
pos_tags
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [('The', 'DT'),
#  ('students', 'NNS'),
#  ('are', 'VBP'),
#  ('studying', 'VBG'),
#  ('natural', 'JJ'),
#  ('language', 'NN'),
#  ('processing', 'NN'),
#  ('to', 'TO'),
#  ('improve', 'VB'),
#  ('their', 'PRP$'),
#  ('understanding', 'NN'),
#  ('of', 'IN'),
#  ('grammar', 'NN'),
#  ('.', '.')]

# %%
print("POS Tags using NLTK:")
for word, tag in pos_tags:
    print(word, ":", tag)
# Out:
# POS Tags using NLTK:
# The : DT
# students : NNS
# are : VBP
# studying : VBG
# natural : JJ
# language : NN
# processing : NN
# to : TO
# improve : VB
# their : PRP$
# understanding : NN
# of : IN
# grammar : NN
# . : .
