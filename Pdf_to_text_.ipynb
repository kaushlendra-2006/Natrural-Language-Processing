# %%
import PyPDF2

# %%
import pandas as pd

# %%
myfile=open(r"C:\Users\Sahil\OneDrive\Documents\Desktop\somatosensory.pdf",'rb')

# %%
pdf_read = PyPDF2.PdfReader(myfile)

# %%
len(pdf_read.pages)
# Out:
# 4

# %%
one = pdf_read.pages[0]

# %%
print(one.extract_text())
# Out:
# This is a sample document to
# showcase page-based formatting. It
# contains a chapter from a Wikibook
# called Sensory Systems . None of the
# content has been changed in this
# article, but some content has been
# remo ved.Anat omy of the Somat osensor y System
# FROM WIKIBOOKS1
# Our somatosensor y system c onsists of sensors in the skin
# and sensors in our muscles, tendons, and joints. The re-
# ceptors in the skin, the so called cutaneous rec eptors, tell
# us about temperature ( thermorec eptors ), pressure and sur-
# face texture ( mechano rec eptors ), and pain ( nocic eptors ).
# The rec eptors in muscles and joints pro vide inf ormation
# about muscle length, muscle tension, and joint angles.
# Cutaneous r ecept ors
# Sensor y inf ormation from Meissner c orpuscles and rapidly
# adap ting aff erents leads to adjustment of grip f orce when
# objec ts are lif ted. These aff erents respond with a brief
# burst of ac tion po tentials when objec ts mo ve a small dis-
# ...

# %%
myfile.close()

# %%
x=open(r"C:\Users\Sahil\OneDrive\Documents\Desktop\somatosensory.pdf",'rb')

# %%
pdf = PyPDF2.PdfReader(x)

# %%
first = pdf.pages[0]

# %%
pdf_weiter = PyPDF2.PdfWriter(x)

# %%
pdf_weiter.add_page(first)
# Out:
# {'/Type': '/Page',
#  '/MediaBox': [0, 0, 566.9291, 708.6614],
#  '/Contents': {'/Filter': '/FlateDecode'},
#  '/Resources': {'/Font': {'/F1': {'/Type': '/Font',
#     '/Subtype': '/TrueType',
#     '/BaseFont': '/PXAAAA+PdbpbbLato-Regular',
#     '/FirstChar': 1,
#     '/LastChar': 42,
#     '/Widths': [193,
#      703,
#      300,
#      300,
#      347,
#      753,
#      581,
#      566,
#      734,
#      756,
#      307,
#      514,
#      920,
#      611,
#      644,
#      530,
#      590,
#      680,
#      507,
#      559,
#      467,
#      559,
#      524,
#      337,
#      511,
#      556,
#      256,
#      524,
#      256,
#      821,
#      556,
#      556,
#      552,
#      403,
#      434,
#      373,
#      556,
#      512,
#      504,
#      512,
#      212,
#      570],
#     '/FontDescriptor': {'/Type': '/FontDescriptor',
#      '/FontName': '/PdbpbbLato-Regular',
#      '/Ascent': 987,
#      '/Descent': -213,
#      '/ItalicAngle': 0,
#      '/StemV': 0,
# ...

# %%
pdf_output = open("new_doc.pdf" , "wb")

# %%
pdf_weiter.write(pdf_output)
# Out:
# (False, <_io.BufferedWriter name='new_doc.pdf'>)

# %%
pdf_output.close()
x.close()

# %%
x=open("new_doc.pdf","rb")

# %%
pdf = PyPDF2.PdfReader(x)

# %%
len(pdf.pages)
# Out:
# 1

# %%
one = pdf.pages[0]

# %%
print(one.extract_text())
# Out:
# This is a sample document to
# showcase page-based formatting. It
# contains a chapter from a Wikibook
# called Sensory Systems . None of the
# content has been changed in this
# article, but some content has been
# remo ved.Anat omy of the Somat osensor y System
# FROM WIKIBOOKS1
# Our somatosensor y system c onsists of sensors in the skin
# and sensors in our muscles, tendons, and joints. The re-
# ceptors in the skin, the so called cutaneous rec eptors, tell
# us about temperature ( thermorec eptors ), pressure and sur-
# face texture ( mechano rec eptors ), and pain ( nocic eptors ).
# The rec eptors in muscles and joints pro vide inf ormation
# about muscle length, muscle tension, and joint angles.
# Cutaneous r ecept ors
# Sensor y inf ormation from Meissner c orpuscles and rapidly
# adap ting aff erents leads to adjustment of grip f orce when
# objec ts are lif ted. These aff erents respond with a brief
# burst of ac tion po tentials when objec ts mo ve a small dis-
# ...

# %%
x.close()
